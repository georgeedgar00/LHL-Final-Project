# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/pre_processed_data.csv')

# %%
df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\r\nLocation: Albuquerque, NM\r\...     3.8
# 1  What You Will Do:\r\n\r\nI. General Summary\r\...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\r\nJob ID: 310709\r...     3.8
# 4  Data Scientist\r\nAffinity Solutions / Marketi...     2.9
#
#                                    Company Name         Location  \
# 0                      Tecolote Research\r\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\r\n3.4    Linthicum, MD
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Hourly', 'Employer provided', 'Lower Salary', 'Upper Salary',
#        'Avg Salary(K)', 'company_txt', 'Job Location', 'Age', 'Python',
#        'spark', 'aws', 'excel', 'sql', 'sas', 'keras', 'pytorch', 'scikit',
#        'tensor', 'hadoop', 'tableau', 'bi', 'flink', 'mongo', 'google_an',
#        'job_title_sim', 'seniority_by_title', 'Degree', 'hourly',
#        'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'job_state', 'same_state', 'age', 'python', 'R',
#        'spark_yn', 'AWS', 'excel_yn'],
#       dtype='object')

# %% [markdown]
# # Job title and seniority

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
            return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'

# %%
df['job_simp'] = df['Job Title'].apply(title_simplifier)
df.job_simp.value_counts()
# Out:
# job_simp
# data scientist    279
# na                184
# data engineer     119
# analyst           102
# manager            22
# mle                22
# director           14
# Name: count, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(seniority)
df.seniority.value_counts()
# Out:
# seniority
# na        520
# senior    220
# jr          2
# Name: count, dtype: int64

# %% [markdown]
# #  Fix state Los Angeles

# %%
df['job_state'] = df.job_state.apply(lambda x: x.strip() if x.strip().lower() != 'los angeles' else 'CA')
df.job_state.value_counts()
# Out:
# job_state
# CA    152
# MA    103
# NY     72
# VA     41
# IL     40
# MD     35
# PA     33
# TX     28
# NC     21
# WA     21
# NJ     17
# FL     16
# OH     14
# TN     13
# DC     11
# CO     11
# WI     10
# UT     10
# IN     10
# AZ      9
# MO      9
# AL      8
# GA      6
# DE      6
# KY      6
# MI      6
# CT      5
# IA      5
# LA      4
# OR      4
# NE      4
# NM      3
# KS      3
# ID      2
# MN      2
# RI      1
# SC      1
# Name: count, dtype: int64

# %% [markdown]
# #  Job description length

# %%
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0      2555
# 1      4828
# 2      3495
# 3      3926
# 4      2748
#        ...
# 737    6219
# 738    6167
# 739    3107
# 740    1678
# 741    3710
# Name: desc_len, Length: 742, dtype: int64

# %% [markdown]
# # Competitor count

# %%
df['num_comp'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)
df['Competitors']
# Out:
# 0                                                     -1
# 1                                                     -1
# 2                                                     -1
# 3      Oak Ridge National Laboratory, National Renewa...
# 4                   Commerce Signals, Cardlytics, Yodlee
#                              ...
# 737                           Pfizer, AstraZeneca, Merck
# 738                      See Tickets, TicketWeb, Vendini
# 739                                                   -1
# 740                                                   -1
# 741                                                   -1
# Name: Competitors, Length: 742, dtype: object

# %% [markdown]
# # Hourly wage to annual

# %%
df['min_salary'] = df.apply(lambda x: x.min_salary*2 if x.hourly ==1 else x.min_salary, axis =1)
df['max_salary'] = df.apply(lambda x: x.max_salary*2 if x.hourly ==1 else x.max_salary, axis =1)

# %%
df[df.hourly ==1][['hourly','min_salary','max_salary']]
# Out:
#      hourly  min_salary  max_salary
# 165       1          34          48
# 177       1          42          68
# 197       1          36          50
# 202       1          42          68
# 210       1          30          50
# 246       1          34          48
# 271       1          42          68
# 337       1          36          50
# 345       1          48          78
# 357       1          42          68
# 363       1          50          56
# 408       1          42          58
# 409       1          20          34
# 492       1          36          50
# 509       1          48          78
# 533       1          42          68
# 542       1          50          56
# 617       1          42          58
# 618       1          20          34
# 645       1          54          94
# 666       1          36          50
# 682       1          48          78
# 711       1          42          68
# 724       1          50          56

# %%
df.describe()
# Out:
#            Rating      Founded      Hourly  Employer provided  Lower Salary  \
# count  742.000000   742.000000  742.000000         742.000000    742.000000
# mean     3.618868  1837.154987    0.032345           0.022911     74.754717
# std      0.801210   497.183763    0.177034           0.149721     30.945892
# min     -1.000000    -1.000000    0.000000           0.000000     15.000000
# 25%      3.300000  1939.000000    0.000000           0.000000     52.000000
# 50%      3.700000  1988.000000    0.000000           0.000000     69.500000
# 75%      4.000000  2007.000000    0.000000           0.000000     91.000000
# max      5.000000  2019.000000    1.000000           1.000000    202.000000
#
#        Upper Salary  Avg Salary(K)         Age      Python       spark  ...  \
# count    742.000000     742.000000  742.000000  742.000000  742.000000  ...
# mean     128.214286     101.484501   47.524259    0.528302    0.225067  ...
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Hourly', 'Employer provided', 'Lower Salary', 'Upper Salary',
#        'Avg Salary(K)', 'company_txt', 'Job Location', 'Age', 'Python',
#        'spark', 'aws', 'excel', 'sql', 'sas', 'keras', 'pytorch', 'scikit',
#        'tensor', 'hadoop', 'tableau', 'bi', 'flink', 'mongo', 'google_an',
#        'job_title_sim', 'seniority_by_title', 'Degree', 'hourly',
#        'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'job_state', 'same_state', 'age', 'python', 'R',
#        'spark_yn', 'AWS', 'excel_yn', 'job_simp', 'seniority', 'desc_len',
#        'num_comp'],
#       dtype='object')

# %%
df.Rating.hist()
# Out:
# <Axes: >

# %%
df.avg_salary.hist()
# Out:
# <Axes: >

# %%
df.age.hist()
# Out:
# <Axes: >

# %%
df.desc_len.hist()
# Out:
# <Axes: >

# %%
df.boxplot(column = ['age','avg_salary','Rating'])
# Out:
# <Axes: >

# %%
df.boxplot(column = 'Rating')
# Out:
# <Axes: >

# %%
df[['age','avg_salary','Rating','desc_len']].corr()
# Out:
#                  age  avg_salary    Rating  desc_len
# age         1.000000    0.019410  0.026164  0.165891
# avg_salary  0.019410    1.000000  0.013492  0.078093
# Rating      0.026164    0.013492  1.000000 -0.012631
# desc_len    0.165891    0.078093 -0.012631  1.000000

# %%
# Custom blue color palette
cmap = sns.color_palette("Blues")

# Create a heatmap to show correlations
plt.figure(figsize=(10, 8))
sns.heatmap(df[['age', 'avg_salary', 'Rating', 'desc_len', 'num_comp']].corr(),
            vmax=.3, center=0, cmap=cmap, square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.title('Correlation Heatmap', fontsize=16)
plt.show()

# %%
df_cat = df[['Location', 'Headquarters', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue', 'company_txt', 'job_state','same_state', 'python', 'R',
       'spark', 'aws', 'excel', 'job_simp', 'seniority']]

# %%
# Loop through categorical columns
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("Graph for %s: Total = %d" % (i, len(cat_num)))

    # Create a bar plot with blue color, darker for higher counts, and black border
    plt.figure(figsize=(10, 6))  # Adjust figure size as needed
    chart = sns.barplot(x=cat_num.index, y=cat_num, palette=sns.color_palette("Blues_r", n_colors=len(cat_num)))
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90, fontsize=12)
    chart.set_yticklabels(chart.get_yticklabels(), fontsize=12)
    plt.xlabel(i.capitalize(), fontsize=14)
    plt.ylabel('Count', fontsize=14)
    plt.title("Distribution of %s" % i.capitalize(), fontsize=16)
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['right'].set_visible(False)
    plt.gca().spines['bottom'].set_color('black')
    plt.gca().spines['left'].set_color('black')
    plt.gca().tick_params(axis='x', colors='black')
    plt.gca().tick_params(axis='y', colors='black')
    plt.show()
# Out:
# Graph for Location: Total = 200
# C:\Users\Goerge\AppData\Local\Temp\ipykernel_23384\2323191722.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart.set_yticklabels(chart.get_yticklabels(), fontsize=12)
# Graph for Headquarters: Total = 198
# C:\Users\Goerge\AppData\Local\Temp\ipykernel_23384\2323191722.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart.set_yticklabels(chart.get_yticklabels(), fontsize=12)
# Graph for Size: Total = 8
# C:\Users\Goerge\AppData\Local\Temp\ipykernel_23384\2323191722.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart.set_yticklabels(chart.get_yticklabels(), fontsize=12)
# Graph for Type of ownership: Total = 9
# C:\Users\Goerge\AppData\Local\Temp\ipykernel_23384\2323191722.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart.set_yticklabels(chart.get_yticklabels(), fontsize=12)
# ...

# %%
# Loop through specific categorical columns
for i in df_cat[['Location', 'Headquarters', 'company_txt']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print("Graph for %s: Total = %d" % (i, len(cat_num)))

    # Create a bar plot with blue color, darker for higher counts, and black border
    plt.figure(figsize=(10, 6))  # Adjust figure size as needed
    chart = sns.barplot(x=cat_num.index, y=cat_num, palette=sns.color_palette("Blues_r", n_colors=len(cat_num)))
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90, fontsize=12)
    chart.set_yticklabels(chart.get_yticklabels(), fontsize=12)
    plt.xlabel(i.capitalize(), fontsize=14)
    plt.ylabel('Count', fontsize=14)
    plt.title("Distribution of %s" % i.capitalize(), fontsize=16)
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['right'].set_visible(False)
    plt.gca().spines['bottom'].set_color('black')
    plt.gca().spines['left'].set_color('black')
    plt.gca().tick_params(axis='x', colors='black')
    plt.gca().tick_params(axis='y', colors='black')
    plt.show()
# Out:
# Graph for Location: Total = 20
# C:\Users\Goerge\AppData\Local\Temp\ipykernel_23384\3682359200.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart.set_yticklabels(chart.get_yticklabels(), fontsize=12)
# Graph for Headquarters: Total = 20
# C:\Users\Goerge\AppData\Local\Temp\ipykernel_23384\3682359200.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart.set_yticklabels(chart.get_yticklabels(), fontsize=12)
# Graph for company_txt: Total = 20
# C:\Users\Goerge\AppData\Local\Temp\ipykernel_23384\3682359200.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart.set_yticklabels(chart.get_yticklabels(), fontsize=12)

# %%
# Grouping and plotting average salary per annum for different states
g = df.groupby("Job Location")["Avg Salary(K)"].mean().sort_values(ascending=False)[0:10]
g = g.reset_index().rename(columns={"Job Location": "Job Location", "Avg Salary(K)": "Average Salary"})

# Create a bar plot with blue color, darker for higher counts, and black border
plt.figure(figsize=(10, 6))
chart = sns.barplot(y="Job Location", x="Average Salary", data=g, palette=sns.color_palette("Blues_r", n_colors=len(g)))
chart.set_yticklabels(chart.get_yticklabels(), fontsize=12)
plt.xlabel('Average Salary (K)', fontsize=14, color='black')
plt.ylabel('States', fontsize=14, color='black')
plt.title('\n Average Salary for Different States \n', size=16, color='black')

# Add a black border around each bar
for bar in chart.patches:
    bar.set_edgecolor('black')

# Add legend and other customizations
patches = [plt.patches.Patch(color=sns.color_palette("Blues_r")[i], label=j) for i, j in zip(range(0, 10), lab)]
plt.legend(handles=patches, bbox_to_anchor=(1, 1), loc=2, borderaxespad=0., fontsize=12)
plt.xticks(fontsize=13)
plt.yticks(fontsize=12)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')
plt.gca().tick_params(axis='x', colors='black')
plt.gca().tick_params(axis='y', colors='black')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 18
#      15     bar.set_edgecolor('black')
#      17 # Add legend and other customizations
# ---> 18 patches = [plt.patches.Patch(color=sns.color_palette("Blues_r")[i], label=j) for i, j in zip(range(0, 10), lab)]
#      19 plt.legend(handles=patches, bbox_to_anchor=(1, 1), loc=2, borderaxespad=0., fontsize=12)
#      20 plt.xticks(fontsize=13)
#
# NameError: name 'lab' is not defined

# %%
# Create a pivot table and plot a barplot for 'job_simp' and 'avg_salary'
pivot_table = pd.pivot_table(df, index='job_simp', values='avg_salary')
pivot_table = pivot_table.sort_values(by='avg_salary', ascending=False)

# Create a bar plot with blue color, darker for higher salaries, and black border
plt.figure(figsize=(10, 6))
chart = sns.barplot(x=pivot_table.index, y='avg_salary', data=pivot_table, palette=sns.color_palette("Blues_r", n_colors=len(pivot_table)))
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, fontsize=12)
chart.set_yticklabels(chart.get_yticklabels(), fontsize=12)
plt.xlabel('Job Simplified', fontsize=14, color='black')
plt.ylabel('Average Salary', fontsize=14, color='black')
plt.title('\n Average Salary by Job Simplified \n', size=16, color='black')

# Add a black border around each bar
for bar in chart.patches:
    bar.set_edgecolor('black')

# Beautify the plot
plt.xticks(fontsize=13)
plt.yticks(fontsize=12)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_color('black')
plt.gca().spines['left'].set_color('black')
plt.gca().tick_params(axis='x', colors='black')
plt.gca().tick_params(axis='y', colors='black')

plt.show()
# Out:
# C:\Users\Goerge\AppData\Local\Temp\ipykernel_23384\810248232.py:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   chart.set_yticklabels(chart.get_yticklabels(), fontsize=12)

# %%
pd.pivot_table(df, index = 'job_simp', values = 'avg_salary')
# Out:
#                 avg_salary
# job_simp
# analyst          65.857843
# data engineer   105.403361
# data scientist  117.564516
# director        168.607143
# manager          84.022727
# mle             126.431818
# na               84.853261

# %%
pd.pivot_table(df, index = ['job_simp', 'seniority'], values = 'avg_salary')
# Out:
#                           avg_salary
# job_simp       seniority
# analyst        jr          56.500000
#                na          61.155405
#                senior      79.092593
# data engineer  na          96.701220
#                senior     124.689189
# data scientist jr         106.500000
#                na         107.043011
#                senior     138.956522
# director       na         168.607143
# manager        na          84.022727
# mle            na         119.133333
#                senior     142.071429
# na             na          73.988189
#                senior     109.061404

# %%
pd.pivot_table(df, index = ['job_state','job_simp'], values = 'avg_salary').sort_values('job_state', ascending = True)
# Out:
#                           avg_salary
# job_state job_simp
# AL        analyst          62.200000
#           data engineer    65.000000
#           na               43.750000
# AZ        analyst          55.000000
#           data engineer    79.500000
#           data scientist   69.500000
#           na              124.500000
# CA        mle             177.300000
#           manager          80.611111
#           na               99.907407
#           data engineer   129.540000
#           analyst          85.250000
#           data scientist  142.522059
# CO        analyst          29.500000
#           data engineer    99.000000
#           data scientist  108.666667
#           mle             100.500000
#           na               31.500000
# CT        data scientist   84.000000
#           na               62.500000
# DC        analyst          63.500000
#           data engineer    85.000000
#           data scientist  149.000000
# DE        na               27.500000
# ...

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

# %%
pd.pivot_table(df, index = ['job_state','job_simp'], values = 'avg_salary', aggfunc = 'count').sort_values('job_state', ascending = True)
# Out:
#                           avg_salary
# job_state job_simp
# AL        analyst                  5
#           data engineer            1
#           na                       2
# AZ        analyst                  1
#           data engineer            5
#           data scientist           1
#           na                       2
# CA        mle                      5
#           manager                  9
#           na                      27
#           data engineer           25
#           analyst                 18
#           data scientist          68
# CO        analyst                  1
#           data engineer            3
#           data scientist           3
#           mle                      1
#           na                       3
# CT        data scientist           2
#           na                       3
# DC        analyst                  2
#           data engineer            4
#           data scientist           5
# DE        na                       6
# ...

# %%
pd.pivot_table(df[df.job_simp == 'data scientist'], index = 'job_state', values = 'avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#            avg_salary
# job_state
# DC         149.000000
# CA         142.522059
# UT         140.500000
# MO         127.666667
# IL         117.233333
# NC         117.000000
# NY         115.250000
# MA         113.750000
# WI         113.500000
# PA         113.333333
# MD         109.115385
# CO         108.666667
# VA         108.416667
# NJ         106.875000
# MI         106.625000
# OH         105.285714
# TX         100.730769
# WA          99.764706
# OR          98.500000
# FL          97.357143
# TN          96.000000
# IN          84.500000
# KY          84.000000
# CT          84.000000
# GA          81.333333
# NM          74.333333
# AZ          69.500000

# %%
# rating, industry, sector, revenue, number of comp, hourly, employer provided, python, r, spark, aws, excel, desc_len, Type of onwership

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'num_comp', 'hourly', 'employer_provided', 'python', 'R', 'spark', 'aws', 'excel', 'Type of ownership','avg_salary']]

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots,index =i, values = 'avg_salary').sort_values('avg_salary', ascending = False))
# Out:
# Rating
#         avg_salary
# Rating
# -1.0    136.181818
#  5.0    134.700000
#  2.5    120.000000
#  4.5    117.714286
#  4.1    116.368421
#  3.9    113.071429
#  2.6    109.083333
#  4.4    108.606061
#  3.2    105.500000
#  4.0    105.340426
#  3.5    104.897959
#  3.7    104.131148
#  4.7    103.983871
#  4.3    102.468750
#  3.3    101.858974
#  4.2    100.442308
#  2.2     97.750000
#  4.6     97.250000
#  3.8     96.811475
#  2.1     95.900000
#  3.4     93.011364
#  1.9     87.500000
#  3.1     86.580000
#  3.0     85.588235
#  3.6     85.467391
#  2.8     83.928571
#  2.7     83.250000
#  2.3     81.500000
#  2.9     81.138889
#  4.8     80.277778
#  2.4     60.214286
# Industry
#                                           avg_salary
# Industry
# Other Retail Stores                       163.500000
# Motion Picture Production & Distribution  146.000000
# Financial Analytics & Research            145.125000
# Health, Beauty, & Fitness                 139.500000
# ...

# %%
pd.pivot_table(df_pivots, index = 'Revenue', columns = 'python', values = 'avg_salary', aggfunc = 'count')
# Out:
# python                             0    1
# Revenue
# $1 to $2 billion (USD)            16   44
# $1 to $5 million (USD)             1    7
# $10 to $25 million (USD)          16   16
# $10+ billion (USD)                66   58
# $100 to $500 million (USD)        47   44
# $2 to $5 billion (USD)            17   22
# $25 to $50 million (USD)          24   16
# $5 to $10 billion (USD)            9   10
# $5 to $10 million (USD)            9    9
# $50 to $100 million (USD)         21   25
# $500 million to $1 billion (USD)  29   28
# Less than $1 million (USD)         1    3
# Unknown / Non-Applicable          94  110

# %%
df
df.to_csv('eda_data.csv', index = False)
